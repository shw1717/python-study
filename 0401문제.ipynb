# %% [markdown]
# <a href="https://colab.research.google.com/github/shw1717/python-study/blob/main/0401%EB%AC%B8%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nums = list(map(int, input("숫자 3개 입력: ". split())))
desc = sorted (nums, reverse=True)
print("큰 순서: ", desc)
asc = sorted(nums)
print("작은 순서: ", asc)
# Out:
# ['숫자', '3개', '입력:']123
# 큰 순서:  [3, 2, 1]
# 작은 순서:  [1, 2, 3]
