# %% [markdown]
# <a href="https://colab.research.google.com/github/shw1717/python-study/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=10

if True:
    print(a)
    print(a)
print(a)
# Out:
# 10
# 10
# 10

# %%
if True:
    print(10)
    print(5)
# Out:
# 10
# 5

# %%
if True: print(10)
# Out:
# 10

# %%
if True: print(10); print(5)
# Out:
# 10
# 5

# %%
if False: print(10); print(5)

# %%
# a: 이 변수는 나이를 저장
a = 10

# %%
print(print.__doc__)
# Out:
# Prints the values to a stream, or to sys.stdout by default.
#
#   sep
#     string inserted between values, default a space.
#   end
#     string appended after the last value, default a newline.
#   file
#     a file-like object (stream); defaults to the current sys.stdout.
#   flush
#     whether to forcibly flush the stream.

# %%
a, b, c = 10, 5.2, "kopo"
print(a)
print(b)
print(c)
# Out:
# 10
# 5.2
# kopo

# %%
a = b = c = "kopo"
print(a)
print(b)
print(c)
# Out:
# kopo
# kopo
# kopo

# %%
a = 10

# %%
print(id(10), id(a))
# Out:
# 11654664 11654664

# %%
b = a
print(id(b))
# Out:
# 11654664

# %%
a = a + 1
print(a)
print(id(a))
# Out:
# 11
# 11654696

# %%
print(id(10), id(11))
# Out:
# 11654664 11654696

# %%
num1 = num2 = num3 = 20

# %%
list_1 = [1,2,3,4,5]

print(list_1[0])
# Out:
# 1

# %%
print(list_1[0] + list_1[1])
# Out:
# 3

# %%
list_1[0:2]
# Out:
# [1, 2]

# %%
list_2 = [0:4]
# Out:
#   File "/tmp/ipykernel_223/2791149817.py", line 1
#     list_2 = [0:4]
#                ^
# SyntaxError: invalid syntax

# %%
list_1 = [10,2,3]

# %%
사람_1 = ["송현우", 28, ["아버지", "어머니", "남동생"]]
print(사람_1[2][0])
# Out:
# 아버지

# %%
s = 'Hello world!'
s[5]
# Out:
# ' '

# %%
문자열_1 = "송현우 이동현"
enumerate(문자열_1)

# %%
print(list(enumerate(문자열_1)))
# Out:
# [(0, '송'), (1, '현'), (2, '우'), (3, ' '), (4, '이'), (5, '동'), (6, '현')]

# %%
list_1=["서지섭", "고규현", "김기욱"]
print(list(enumerate(list_1)))
# Out:
# [(0, '서지섭'), (1, '고규현'), (2, '김기욱')]

# %%
print(1,2,3,4,"t", sep='\n')
# Out:
# 1
# 2
# 3
# 4
# t

# %%
print(1,2,3,'\n',4,"t")
# Out:
# 1 2 3
#  4 t

# %%
print(1,2,3, end='\t')
print(4,5,6, end='\t')
# Out:
# 1 2 3	4 5 6

# %%
num = input('Enter a number:')
print(num)
print(type(num))
# Out:
# Enter a number:11
# 11
