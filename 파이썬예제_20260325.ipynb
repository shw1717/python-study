# %% [markdown]
# <a href="https://colab.research.google.com/github/shw1717/python-study/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC%EC%98%88%EC%A0%9C_20260325.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 문제] 컴퓨터와 가위바위보 게임을 코딩해 보세요. 5전 3승제로 먼저 이기는 사람을 알려주고, 축하의 인사도 출력해 보세요

# %%
# 사용자_가바보 = input("가위, 바위, 보 중에 하나를 선택/입력해 주세요: ")
# if 사용자_가바보 in ['가위', '바위', '보']:
#     print("사용자가 선택한 것은 {} 입니다".format(사용자_가바보))
# else:
#     print("사용자가 잘못 선택했어요")

사용자_가바보 = None
while True:
    사용자_가바보 = input("가위, 바위, 보 중에 하나를 선택/입력해 주세요: ")
    if 사용자_가바보 in ['가위', '바위', '보']:
        break
    print("사용자가 잘못 선택했어요")
# Out:
# 가위, 바위, 보 중에 하나를 선택/입력해 주세요: 가바
# 사용자가 잘못 선택했어요
# 가위, 바위, 보 중에 하나를 선택/입력해 주세요: 가바바
# 사용자가 잘못 선택했어요
# 가위, 바위, 보 중에 하나를 선택/입력해 주세요: 가바바밥
# 사용자가 잘못 선택했어요
# 가위, 바위, 보 중에 하나를 선택/입력해 주세요: 가위

# %%
import random

리스트_가바보 = ['가위', '바위', '보']
#컴퓨터_가바보 = random.randint(0,2)
#컴퓨터_가바보 = 리스트_가바보[컴퓨터_가바보]
컴퓨터_가바보 = 리스트_가바보[random.randint(0,2)]

print("컴퓨터가 선택한 것은 {} 입니다".format(컴퓨터_가바보))
# Out:
# 컴퓨터가 선택한 것은 가위 입니다

# %%
리스트_가바보 = {0:'가위', 1:'바위', 2:'보'}
컴퓨터_가바보 = random.randint(0,2)
컴퓨터_가바보 = 리스트_가바보[컴퓨터_가바보]

print("컴퓨터가 선택한 것은 {} 입니다".format(컴퓨터_가바보))
# Out:
# 컴퓨터가 선택한 것은 가위 입니다

# %%
if 사용자_가바보 == '바위' and 컴퓨터_가바보 == '가위':
    pass
elif 사용자_가바보 == '바위' and 컴퓨터_가바보 == '보':
    pass
else:
    pass

# %%
if 사용자_가바보 == '바위':
    if 컴퓨터_가바보 == '가위':
        pass
    elif 컴퓨터_가바보 == '보':
        pass
    else:
        pass
elif 사용자_가바보 == '가위':
    pass
else:
    pass
